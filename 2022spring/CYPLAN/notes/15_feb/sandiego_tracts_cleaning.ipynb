# %% [markdown]
# # San Diego Tracts
#
# This dataset contains an extract of a set of variables from the 2017 ACS Census Tracts for the San Diego (CA) metropolitan area.

# %%
# !pip install cenpy
# !pip install python-Levenshtein
# Out:
# Collecting cenpy
#   Downloading cenpy-1.0.0.post4.tar.gz (30 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from cenpy) (1.2.4)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.9/site-packages (from cenpy) (0.10.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from cenpy) (2.25.1)
# Collecting rtree
#   Downloading Rtree-0.9.7-cp39-cp39-macosx_10_15_x86_64.whl (426 kB)
#      |████████████████████████████████| 426 kB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from cenpy) (1.20.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from cenpy) (1.15.0)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: libpysal in /usr/local/lib/python3.9/site-packages (from cenpy) (4.6.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.9/site-packages (from geopandas->cenpy) (3.3.0)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.9/site-packages (from geopandas->cenpy) (1.8.0)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.9/site-packages (from geopandas->cenpy) (1.8.21)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (0.7.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (8.0.1)
# Requirement already satisfied: munch in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (2.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (2020.12.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (57.0.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (20.3.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->cenpy) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas->cenpy) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->cenpy) (2.8.1)
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.9/site-packages (from libpysal->cenpy) (1.6.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/site-packages (from libpysal->cenpy) (4.9.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from libpysal->cenpy) (3.0.1)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.9/site-packages (from libpysal->cenpy) (1.4.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from libpysal->cenpy) (20.9)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/site-packages (from beautifulsoup4->libpysal->cenpy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->libpysal->cenpy) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->libpysal->cenpy) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests->cenpy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->cenpy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->cenpy) (1.26.4)
# Building wheels for collected packages: cenpy
#   Building wheel for cenpy (setup.py) ... done
#   Created wheel for cenpy: filename=cenpy-1.0.0.post4-py3-none-any.whl size=29924 sha256=a1c782be9cda7f926ab30544e970824629a7ee34e1b16c74b133a59b2777a8f5
#   Stored in directory: /Users/mason/Library/Caches/pip/wheels/94/53/3c/6683b7375d2e8b74e8aa99949599594c014f558bddc6c491b1
# Successfully built cenpy
# Installing collected packages: rtree, fuzzywuzzy, cenpy
# Successfully installed cenpy-1.0.0.post4 fuzzywuzzy-0.18.0 rtree-0.9.7
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from python-Levenshtein) (57.0.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp39-cp39-macosx_11_0_x86_64.whl size=80809 sha256=f6686ddcf20ddf54163f0f5ec58bc1c32b5fd5700d9a0d8070254e91b31b2681
#   Stored in directory: /Users/mason/Library/Caches/pip/wheels/46/4a/6c/164a1d9dd67c82d208f19d869ad0a517a0c5a6117f608c53e6
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.2
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
pip install contextily
# Out:
# Collecting contextily
#   Downloading contextily-1.2.0-py3-none-any.whl (16 kB)
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#      |████████████████████████████████| 21.2 MB 5.9 MB/s eta 0:00:01
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/site-packages (from contextily) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from contextily) (2.25.1)
# Collecting xyzservices
#   Downloading xyzservices-2022.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/site-packages (from contextily) (3.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/site-packages (from contextily) (8.2.0)
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 48.4 MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib->contextily) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->contextily) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.9/site-packages (from matplotlib->contextily) (1.20.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib->contextily) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->contextily) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->contextily) (1.15.0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.9/site-packages (from mercantile->contextily) (8.0.1)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/site-packages (from rasterio->contextily) (20.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from rasterio->contextily) (57.0.0)
# Collecting affine
#   Downloading affine-2.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from rasterio->contextily) (2020.12.5)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.9/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests->contextily) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->contextily) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->contextily) (2.10)
# Installing collected packages: snuggs, geographiclib, affine, xyzservices, rasterio, mercantile, geopy, contextily
# Successfully installed affine-2.3.0 contextily-1.2.0 geographiclib-1.52 geopy-2.2.0 mercantile-1.2.1 rasterio-1.2.10 snuggs-1.4.7 xyzservices-2022.2.0
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import contextily
import geopandas
import cenpy

acs = cenpy.products.ACS(2017)

# %% [markdown]
# ## Download Data

# %% [markdown]
# - Set variables to download

# %%
vars_to_download = {
    "B25077_001E": "median_house_value",  # Median house value
    "B02001_002E": "total_pop_white",     # Total white population
    "B01003_001E": "total_pop",           # Total population
    "B25003_003E": "total_rented",        # Total rented occupied
    "B25001_001E": "total_housing_units", # Total housing units
    "B09019_006E": "hh_female",           # Female households
    "B09019_001E": "hh_total",            # Total households
    "B15003_002E": "total_bachelor",      # Total w/o Bachelor degree
    "B25018_001E": "median_no_rooms",     # Median number of rooms
    "B19083_001E": "income_gini",         # Gini index of income inequality
    "B01002_001E": "median_age",          # Median age
    "B08303_001E": "tt_work",              # Aggregate travel time to work
    "B19013_001E": "median_hh_income"     # Median household income
}
vars_to_download_l = list(vars_to_download.keys())

# %% [markdown]
# - Download geometries and attributes

# %%
# %%time
db = acs.from_msa("San Diego, CA",
                  level="tract",
                  variables=vars_to_download_l
                 )
# Out:
# /usr/local/lib/python3.9/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /usr/local/lib/python3.9/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# CPU times: user 1.1 s, sys: 90.2 ms, total: 1.19 s
# Wall time: 15.1 s
# /usr/local/lib/python3.9/site-packages/cenpy/products.py:748: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   return self._from_name(

# %% [markdown]
# ## Metadata

# %% [markdown]
# We will also write a companion file with the names of each variable:

# %%
var_names = acs.variables\
               .reindex(vars_to_download)\
               [["label", "concept"]]\
               .reset_index()\
               .rename(columns={"index": "var_id"})
var_names["short_name"] = var_names["var_id"].map(vars_to_download)

# %%
var_names
# Out:
#          var_id                                              label  \
# 0   B25077_001E                   Estimate!!Median value (dollars)
# 1   B02001_002E                       Estimate!!Total!!White alone
# 2   B01003_001E                                    Estimate!!Total
# 3   B25003_003E                   Estimate!!Total!!Renter occupied
# 4   B25001_001E                                    Estimate!!Total
# 5   B09019_006E  Estimate!!Total!!In households!!In family hous...
# 6   B09019_001E                                    Estimate!!Total
# 7   B15003_002E            Estimate!!Total!!No schooling completed
# 8   B25018_001E                   Estimate!!Median number of rooms
# 9   B19083_001E                               Estimate!!Gini Index
# 10  B01002_001E                     Estimate!!Median age --!!Total
# 11  B08303_001E                                    Estimate!!Total
# 12  B19013_001E  Estimate!!Median household income in the past ...
#
#                                               concept           short_name
# 0                              MEDIAN VALUE (DOLLARS)   median_house_value
# 1                                                RACE      total_pop_white
# 2                                    TOTAL POPULATION            total_pop
# 3                                              TENURE         total_rented
# 4                                       HOUSING UNITS  total_housing_units
# 5   HOUSEHOLD TYPE (INCLUDING LIVING ALONE) BY REL...            hh_female
# 6   HOUSEHOLD TYPE (INCLUDING LIVING ALONE) BY REL...             hh_total
# 7   EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...       total_bachelor
# 8                              MEDIAN NUMBER OF ROOMS      median_no_rooms
# 9                     GINI INDEX OF INCOME INEQUALITY          income_gini
# 10                                  MEDIAN AGE BY SEX           median_age
# 11                                TRAVEL TIME TO WORK              tt_work
# 12  MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...     median_hh_income

# %% [markdown]
# ## Process data
#
# While the ACS comes with a large number of attributes, we are not limited to the original variables at hand; we
# can construct additional variables. This is particularly useful when
# we want to compare areas that are not very similar in some structural
# characteristic, such as area or population. For example, a quick look into the
# variable names shows most variables are counts. For tracts of different sizes,
# these variables will mainly reflect their overall population, rather than provide direct information
# about the variables itself. To get around this, we will cast many of these count variables to rates,
# and use them in addition to a subset of the original variables.

# %% [markdown]
# - Replace missing values with columns mean

# %%
filler = lambda col: col.fillna(col.mean()) #you could also put "0" here if you don't want to assume a mean exists
db.loc[:, vars_to_download] = db.loc[:, vars_to_download]\
                                .apply(filler)

# %% [markdown]
# - Replace variable codes with short names

# %%
db = db.rename(columns=vars_to_download)

# %% [markdown]
# - Calculate area in Sq.Km (we use the [Conus Albers](http://epsg.io/5070) CRS)

# %%
db["area_sqkm"] = db.to_crs(epsg=5070).area / 1e6 # the 5070 came from the website above 
                    # stands for Coordinate Reference Frame

# %% [markdown]
# - Percentage of renter occupied units

# %%
db["pct_rented"] = db["total_rented"] / \
                  (db["total_housing_units"] + \
                   (db["total_housing_units"]==0) * 1
                  )

# %% [markdown]
# - Percentage of female households

# %%
db["pct_hh_female"] = db["hh_female"] / \
                  (db["hh_total"] + \
                   (db["hh_total"]==0) * 1
                  )

# %% [markdown]
# - Percentage with a Bachelor's degree

# %%
db["pct_bachelor"] = db["total_bachelor"] / \
                  (db["total_pop"] + \
                   (db["total_pop"]==0) * 1
                  )

# %% [markdown]
# - Percentage of white population

# %%
db["pct_white"] = db["total_pop_white"] / \
                  (db["total_pop"] + \
                   (db["total_pop"]==0) * 1
                  )

# %% [markdown]
# - Generate indicator for subset of contiguous 30 tracts

# %%
tract_geoids = [
     '06073000100',
     '06073000201',
     '06073000202',
     '06073000300',
     '06073000400',
     '06073000500',
     '06073000600',
     '06073000700',
     '06073000800',
     '06073000900',
     '06073001000',
     '06073001100',
     '06073001200',
     '06073001300',
     '06073001400',
     '06073001500',
     '06073001600',
     '06073001700',
     '06073001800',
     '06073001900',
     '06073002001',
     '06073002002',
     '06073002100',
     '06073002201',
     '06073002202',
     '06073002301',
     '06073002302',
     '06073002401',
     '06073002402',
     '06073002501'
]
db["sub_30"] = False
db.loc[db["GEOID"].isin(tract_geoids), "sub_30"] = True

# %%
ax = db.plot(figsize=(15, 15),alpha=0.5, color="k")
db[db["sub_30"]].plot(ax=ax, color="yellow")
contextily.add_basemap(ax, crs=db.crs);

# %% [markdown]
# ## Write Out

# %%
db.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 628 entries, 0 to 627
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GEOID                628 non-null    object
#  1   geometry             628 non-null    geometry
#  2   median_age           628 non-null    float64
#  3   total_pop            628 non-null    float64
#  4   total_pop_white      628 non-null    float64
#  5   tt_work              628 non-null    float64
#  6   hh_total             628 non-null    float64
#  7   hh_female            628 non-null    float64
#  8   total_bachelor       628 non-null    float64
#  9   median_hh_income     628 non-null    float64
#  10  income_gini          628 non-null    float64
#  11  total_housing_units  628 non-null    float64
#  12  total_rented         628 non-null    float64
#  13  median_no_rooms      628 non-null    float64
#  14  median_house_value   628 non-null    float64
#  15  NAME                 628 non-null    object
#  16  state                628 non-null    object
#  17  county               628 non-null    object
#  18  tract                628 non-null    object
#  19  area_sqkm            628 non-null    float64
#  20  pct_rented           628 non-null    float64
#  21  pct_hh_female        628 non-null    float64
#  22  pct_bachelor         628 non-null    float64
#  23  pct_white            628 non-null    float64
#  24  sub_30               628 non-null    bool
# dtypes: bool(1), float64(18), geometry(1), object(5)
# memory usage: 123.3+ KB

# %% [markdown]
# - Dataset

# %%
! rm -f sandiego_tracts.gpkg
db.to_file("sandiego_tracts.gpkg", driver="GPKG")

# %% [markdown]
# - Metadata

# %%
! rm -f sandiego_tracts_varnames.json
var_names.to_json("sandiego_tracts_varnames.json")

# %% [markdown]
# See: https://www.gis-blog.com/geopackage-vs-shapefile/

# %% [markdown]
# GeoPackage is an open, portable, and compact format for transferring geospatial information.
